# %% [markdown]
# <a href="https://colab.research.google.com/github/savavision6/AI-Sample/blob/main/SanAi1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# !pip install openai
# !pip install PyPDF2

# %%
# !pip install faiss-cpu
# !pip install tiktoken

# %%
from PyPDF2 import PdfReader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import ElasticVectorSearch, Pinecone, Weaviate, FAISS

# %%
# Get your API keys from openai, you will need to create an account.
# Here is the link to get the keys: https://platform.openai.com/account/billing/overview
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
# connect your Google Drive
#from google.colab import drive
#drive.mount('/content/gdrive', force_remount=True)
#root_dir = "/content/gdrive/My Drive/"
#reader = PdfReader('/content/gdrive/My Drive/Data/MyJavaKM.pdf')
reader = PdfReader('/home/MyJavaKM.pdf')

# %%
reader

# %%
# read data from the file and put them into a variable called raw_text
raw_text = ''
for i, page in enumerate(reader.pages):
    text = page.extract_text()
    if text:
        raw_text += text

# %%
raw_text[:100]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7c6aa5475bb4> in <cell line: 1>()
# ----> 1 raw_text[:100]
#
# NameError: name 'raw_text' is not defined

# %%
# We need to split the text that we read into smaller chunks so that during information retreival we don't hit the token size limits.

text_splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size = 1000,
    chunk_overlap  = 200,
    length_function = len,
)
texts = text_splitter.split_text(raw_text)

# %%
texts[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-94b115c2dee7> in <cell line: 1>()
# ----> 1 texts[0]
#
# NameError: name 'texts' is not defined

# %%
texts[1]
# Out:
# 'generated PDF.  \n2. Installation  \nDownload the iText core binary from the webpage  http://sourceforge.net/projects/itext/ . The \ndownload contains one jar which is required if you want to use iText.  \n \n3. Create a PDF  \nCreate a new Java project "de.vogella.itext.write" with the package "de.voge lla.itext.write". \nCreate a folder "lib" and put the iText library (jar file) into this folder.  Add the jar to your \nclasspath . \nCreate the following class "FirstPdf.java" . I assume that the code is pretty much self -\nexplaining. I tried to add lots of comments to make it easier to understand. For more complex \nexamples have a look at the  iText Homepage . \n4. Formatting your output  \nParagraph allows to set the alignment and the indentation. For this example create project \n"de.vogella.itext.position" similar to the previously created ones. Create the following class \n"PositionPdf.java".'

# %%
# !pip install -U langchain-openai
from langchain_openai import OpenAIEmbeddings

# %%
# Download embeddings from OpenAI
embeddings = OpenAIEmbeddings()

# %%
docsearch = FAISS.from_texts(texts, embeddings)

# %%
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI
chain = load_qa_chain(OpenAI(), chain_type="stuff")
query = "who are the authors of the article?"
docs = docsearch.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ' The authors of the article are not explicitly stated, but it mentions Bruno Lowagie as the creator of the iText library.'

# %%
query = "How to Install iText?"
docs = docsearch.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# ' Download the iText core binary from the webpage http://sourceforge.net/projects/itext/ and add the jar to your classpath.'

# %%
query = "Who created java library for iText?"
docs = docsearch.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# ' Bruno Lowagie'

# %%
query = "Give the steps to create PDF using iText?"
docs = docsearch.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# ' \n1. Download the iText core binary from the webpage http://sourceforge.net/projects/itext/. \n2. Create a new Java project with the package "de.vogella.itext.write". \n3. Create a folder "lib" and put the iText library (jar file) into this folder. \n4. Add the jar to your classpath. \n5. Create a new class "FirstPdf.java" and add the necessary code. \n6. Run the class to create the PDF file.'

# %%
from openai import OpenAI
client = OpenAI()

response = client.embeddings.create(
  model="text-embedding-ada-002",
  input="This is My texts"
)

print(response)
# Out:
# CreateEmbeddingResponse(data=[Embedding(embedding=[-0.027409149333834648, 0.010884595103561878, -0.0036765155382454395, -0.01467970758676529, -0.017750060185790062, 0.025959625840187073, -0.010917538776993752, -0.003811584785580635, 0.0037555804010480642, -0.0023225301411002874, -0.003289427375420928, 0.013862703926861286, -0.02074134536087513, -0.0011612650705501437, 0.00938895158469677, 0.003350373124703765, 0.024338796734809875, 0.02325824461877346, 0.009929227642714977, -0.026249531656503677, 0.0026931464672088623, 0.014508400112390518, 0.0005188630893826485, 0.0023077053483575583, -0.004388099070638418, -0.015707550570368767, -0.003936770837754011, -0.022955162450671196, -0.00947460439056158, -0.0236667450517416, -0.00010016940359491855, -0.019107339903712273, -0.007418918423354626, -0.020398732274770737, -0.024114780128002167, -0.0009652500739321113, -0.0021676947362720966, -0.011490758508443832, 0.012208931148052216, -0.008328163996338844, 0.015918390825390816, 0.0177895911037
# ...
